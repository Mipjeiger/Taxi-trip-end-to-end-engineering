# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
pd.set_option('display.max_columns', None)
df = pd.read_parquet("../../database/parquet/df_ultra_features.parquet")
df['DateTime'] = pd.to_datetime(df['Date'].astype(str) + ' ' + df['Time'].astype(str))
df = df.sort_values(by='DateTime', ascending=True).drop(columns='DateTime').reset_index(drop=True)
df
# Out:
#              Date      Time    Booking ID       Booking Status   Customer ID  \
# 0      2024-01-01  00:19:34  "CNR4352144"            Completed  "CID8362794"
# 1      2024-01-01  01:35:18  "CNR9147645"            Completed  "CID8300238"
# 2      2024-01-01  01:37:50  "CNR1009222"  Cancelled by Driver  "CID2030746"
# 3      2024-01-01  01:48:03  "CNR2740479"  Cancelled by Driver  "CID3231181"
# 4      2024-01-01  01:49:56  "CNR7650148"  Cancelled by Driver  "CID3381661"
# ...           ...       ...           ...                  ...           ...
# 149995 2024-12-30  22:58:00  "CNR9030698"            Completed  "CID6939658"
# 149996 2024-12-30  23:03:14  "CNR1507833"            Completed  "CID9905090"
# 149997 2024-12-30  23:17:05  "CNR2265113"            Completed  "CID4170406"
# 149998 2024-12-30  23:21:12  "CNR4066733"            Completed  "CID8938559"
# 149999 2024-12-30  23:36:11  "CNR6915581"           Incomplete  "CID5185745"
#
#        Vehicle Type   Pickup Location    Drop Location  Avg VTAT  Avg CTAT  \
# 0              Bike        Pasar Baru   Cilandak Timur      10.8      38.9
# 1           Go Mini        Kali Anyar       Rawamangun       8.5      15.1
# 2          Go Sedan           Serdang       Pengadegan       7.4      28.8
# 3              Auto      Tanah Tinggi     Kampung Rawa       5.6      28.8
# 4          Go Sedan              Jati       Batu Ceper       6.2      28.8
# ...             ...               ...              ...       ...       ...
# 149995         Bike              Setu  Kembangan Utara       6.9      35.8
# 149996        eBike        Jatinegara   Grogol Selatan       7.9      33.6
# 149997      Go Mini      Kebon Melati            Galur       9.9      39.9
# 149998      Uber XL      Utan Panjang     Pinang Ranti       2.6      26.7
# 149999         Auto  Mampang Prapatan     Tegal Parang       3.5      11.9
#
#         Booking Value  Ride Distance  Driver Ratings  Customer Rating  \
# 0             99000.0          37.98             4.8              4.8
# 1            114000.0          39.29             4.2              4.1
# 2            414000.0          23.72             4.3              4.5
# 3            414000.0          23.72             4.3              4.5
# 4            414000.0          23.72             4.3              4.5
# ...               ...            ...             ...              ...
# 149995       440000.0          12.85             4.4              4.8
# 149996       279000.0          39.36             3.8              4.3
# 149997         1855.0          38.91             4.3              4.6
# 149998       520000.0          36.37             5.0              4.3
# 149999       571000.0           2.67             4.3              4.5
#
#        Payment Method Cancelled Rides by Customer  \
# 0                Cash             No Cancellation
# 1         Uber Wallet             No Cancellation
# 2          Debit Card             No Cancellation
# 3          Debit Card                   Cancelled
# 4          Debit Card             No Cancellation
# ...               ...                         ...
# 149995            UPI                   Cancelled
# 149996            UPI             No Cancellation
# 149997            UPI                   Cancelled
# 149998    Uber Wallet             No Cancellation
# 149999            UPI             No Cancellation
#
#        Reason for cancelling by Customer Cancelled Rides by Driver  \
# 0                        No Cancellation           No Cancellation
# 1                     No Reason Provided                 Cancelled
# 2                           Changed Mind           No Cancellation
# 3                      Found Alternative                 Cancelled
# 4                      Booked by Mistake                 Cancelled
# ...                                  ...                       ...
# 149995            Driver Taking Too Long                 Cancelled
# 149996                      Changed Mind                 Cancelled
# 149997                 Booked by Mistake           No Cancellation
# 149998                 Booked by Mistake           No Cancellation
# 149999                      Changed Mind                 Cancelled
#
#        Driver Cancellation Reason  Incomplete Rides Incomplete Rides Reason  \
# 0                 No Cancellation               0.0         No Cancellation
# 1                  Personal Issue               1.0   Ride Cancelled Midway
# 2                   Traffic Issue               0.0   Ride Cancelled Midway
# 3                   Traffic Issue               0.0           Route Problem
# 4               Vehicle Breakdown               0.0               App Error
# ...                           ...               ...                     ...
# 149995         No Reason Provided               1.0               App Error
# 149996       Customer Unreachable               0.0      No Reason Provided
# 149997          Vehicle Breakdown               0.0      No Reason Provided
# 149998       Customer Unreachable               0.0       Vehicle Breakdown
# 149999             Personal Issue               0.0      No Reason Provided
#
#                   Datetime  hour  day_of_week  Pickup Encoded  Drop Encoded  \
# 0      2024-01-01 00:19:34     0            0             110            18
# 1      2024-01-01 01:35:18     1            0              47           147
# 2      2024-01-01 01:37:50     1            0             147           125
# 3      2024-01-01 01:48:03     1            0             160            61
# 4      2024-01-01 01:49:56     1            0              40             2
# ...                    ...   ...          ...             ...           ...
# 149995 2024-12-30 22:58:00    22            0             148            84
# 149996 2024-12-30 23:03:14    23            0              41            43
# 149997 2024-12-30 23:17:05    23            0              69            36
# 149998 2024-12-30 23:21:12    23            0             174           132
# 149999 2024-12-30 23:36:11    23            0              94           168
#
#         route_cluster  distance_per_hour  log_distance  distance_squared  \
# 0                   4           4.312727      3.663049         1442.4804
# 1                   3           4.312727      3.696103         1543.7041
# 2                   1           4.312727      3.207613          562.6384
# 3                   2           4.312727      3.207613          562.6384
# 4                   0           4.312727      3.207613          562.6384
# ...               ...                ...           ...               ...
# 149995              2           0.558696      2.628285          165.1225
# 149996              0           1.640000      3.697839         1549.2096
# 149997              4           1.621250      3.686627         1513.9881
# 149998              1           1.515417      3.620868         1322.7769
# 149999              1           0.111250      1.300192            7.1289
#
#         distance_sqrt  is_peak_hour  is_weekend  is_night  hour_sin  hour_cos  \
# 0            6.162792             0           0         1  0.000000  1.000000
# 1            6.268174             0           0         1  0.258819  0.965926
# 2            4.870318             0           0         1  0.258819  0.965926
# 3            4.870318             0           0         1  0.258819  0.965926
# 4            4.870318             0           0         1  0.258819  0.965926
# ...               ...           ...         ...       ...       ...       ...
# 149995       3.584690             0           0         1 -0.500000  0.866025
# 149996       6.273755             0           0         1 -0.258819  0.965926
# 149997       6.237788             0           0         1 -0.258819  0.965926
# 149998       6.030755             0           0         1 -0.258819  0.965926
# 149999       1.634013             0           0         1 -0.258819  0.965926
#
#         day_sin  day_cos  traffic_score  route_avg_ctat_safe  rating_diff  \
# 0           0.0      1.0              1            29.026393         0.00
# 1           0.0      1.0              1            29.026393         0.10
# 2           0.0      1.0              1            29.026393        -0.20
# 3           0.0      1.0              1            29.026393        -0.20
# 4           0.0      1.0              1            29.026393        -0.20
# ...         ...      ...            ...                  ...          ...
# 149995      0.0      1.0              1            25.260000        -0.40
# 149996      0.0      1.0              1            25.633333        -0.50
# 149997      0.0      1.0              1            27.000000        -0.30
# 149998      0.0      1.0              1            25.833333         0.45
# 149999      0.0      1.0              1            29.666667        -0.20
#
#         avg_rating  low_driver_rating  low_customer_rating  driver_score  \
# 0            4.625                  0                    0           4.8
# 1            4.150                  0                    1           0.0
# 2            4.400                  0                    0           4.3
# 3            4.400                  0                    0           0.0
# 4            4.400                  0                    0           0.0
# ...            ...                ...                  ...           ...
# 149995       4.600                  0                    0           0.0
# 149996       4.050                  1                    0           0.0
# 149997       4.450                  0                    0           4.3
# 149998       4.625                  0                    0           5.0
# 149999       4.400                  0                    0           0.0
#
#         hourly_demand  route_demand  demand_pressure  route_count  log_price  \
# 0                1373             5       228.833333            5  11.502885
# 1                1360             2       453.333333            2  11.643962
# 2                1360             4       272.000000            4  12.933624
# 3                1360             7       170.000000            7  12.933624
# 4                1360             7       170.000000            7  12.933624
# ...               ...           ...              ...          ...        ...
# 149995           5441             6       777.285714            6  12.994532
# 149996           2762             4       552.400000            4  12.538971
# 149997           2762             5       460.333333            5   7.526179
# 149998           2762             4       552.400000            4  13.161586
# 149999           2762            10       251.090909           10  13.255146
#
#         log_ctat  log_route_count  log_route_price  log_route_ctat  \
# 0       3.686376         1.791759        12.700787        3.394508
# 1       2.778819         1.098612        12.700787        3.394508
# 2       3.394508         1.609438        12.700787        3.394508
# 3       3.394508         2.079442        12.700787        3.394508
# 4       3.394508         2.079442        12.700787        3.394508
# ...          ...              ...              ...             ...
# 149995  3.605498         1.945910        12.742693        3.268047
# 149996  3.543854         1.609438        12.331425        3.282164
# 149997  3.711130         1.791759        13.003582        3.332205
# 149998  3.321432         1.609438        12.861867        3.289645
# 149999  2.557227         2.397895        12.865608        3.423176
#
#         time_distance_interaction  route_complexity  peak_pressure  \
# 0                           37.98                 5              0
# 1                           39.29                 2              0
# 2                           23.72                 4              0
# 3                           23.72                 7              0
# 4                           23.72                 7              0
# ...                           ...               ...            ...
# 149995                      12.85                 6              0
# 149996                      39.36                 4              0
# 149997                      38.91                 5              0
# 149998                      36.37                 4              0
# 149999                       2.67                10              0
#
#         route_ctat_mean  route_ctat_median  route_ctat_std  route_vtat_mean  \
# 0             30.820000              31.20        9.496684         9.620000
# 1             18.300000              18.30        4.525483         7.000000
# 2             28.750000              28.80        0.100000        10.900000
# 3             25.914286              25.90        3.223057         6.571429
# 4             23.542857              20.60        6.484303         5.514286
# ...                 ...                ...             ...              ...
# 149995        27.016667              26.15        6.237120         8.683333
# 149996        27.625000              27.30       10.463389         7.750000
# 149997        29.580000              28.80        8.277802         8.020000
# 149998        26.050000              26.30        2.487971         6.675000
# 149999        27.890000              28.80        6.833813         8.140000
#
#         route_vtat_median  hour_avg_ctat  hour_avg_vtat  hour_demand  \
# 0                   10.80      29.024763       8.400510         1373
# 1                    7.00      28.935515       8.381618         1360
# 2                    9.20      28.935515       8.381618         1360
# 3                    5.60      28.935515       8.381618         1360
# 4                    6.20      28.935515       8.381618         1360
# ...                   ...            ...            ...          ...
# 149995               7.95      29.112571       8.432659         5441
# 149996               8.60      28.868356       8.447502         2762
# 149997               9.90      28.868356       8.447502         2762
# 149998               6.65      28.868356       8.447502         2762
# 149999               8.35      28.868356       8.447502         2762
#
#         dow_avg_ctat  dow_avg_vtat  distance_bin  dist_bin_ctat  \
# 0          28.940847      8.432545             3      30.060481
# 1          28.940847      8.432545             3      30.060481
# 2          28.940847      8.432545             2      29.119842
# 3          28.940847      8.432545             2      29.119842
# 4          28.940847      8.432545             2      29.119842
# ...              ...           ...           ...            ...
# 149995     28.940847      8.432545             1      28.152500
# 149996     28.940847      8.432545             3      30.060481
# 149997     28.940847      8.432545             3      30.060481
# 149998     28.940847      8.432545             3      30.060481
# 149999     28.940847      8.432545             0      27.916399
#
#         dist_bin_vtat  log_distance_v2  rating_sum  rating_mult  rating_min  \
# 0            8.487883         7.010743         9.6        23.04         4.8
# 1            8.487883         7.105852         8.3        17.22         4.1
# 2            8.707975         5.744773         8.8        19.35         4.3
# 3            8.707975         5.744773         8.8        19.35         4.3
# 4            8.707975         5.744773         8.8        19.35         4.3
# ...               ...              ...         ...          ...         ...
# 149995       8.043096         4.260973         9.2        21.12         4.4
# 149996       8.487883         7.110858         8.1        16.34         3.8
# 149997       8.487883         7.078542         8.9        19.78         4.3
# 149998       8.487883         6.889998         9.3        21.50         4.3
# 149999       7.952362         1.482556         8.8        19.35         4.3
#
#         rating_max  rating_bucket  rating_bucket_ctat  rating_bucket_vtat  \
# 0              4.8              4           29.983461            8.483689
# 1              4.2              3           28.674842            8.418815
# 2              4.5              3           28.674842            8.418815
# 3              4.5              3           28.674842            8.418815
# 4              4.5              3           28.674842            8.418815
# ...            ...            ...                 ...                 ...
# 149995         4.8              4           29.983461            8.483689
# 149996         4.3              3           28.674842            8.418815
# 149997         4.6              3           28.674842            8.418815
# 149998         5.0              4           29.983461            8.483689
# 149999         4.5              3           28.674842            8.418815
#
#        route_hour_key  route_hour_ctat  route_hour_vtat   price_per_km  \
# 0            110_18_0             38.9             10.8    2599.789916
# 1            47_147_1             15.1              8.5    2894.135567
# 2           147_125_1             28.8              7.4   17380.352645
# 3            160_61_1             28.8              5.6   17380.352645
# 4              40_2_1             28.8              6.2   17380.352645
# ...               ...              ...              ...            ...
# 149995      148_84_22             35.8              6.9   33976.833977
# 149996       41_43_23             33.6              7.9    7070.451090
# 149997       69_36_23             39.9              9.9      47.551910
# 149998     174_132_23             26.7              2.6   14258.294489
# 149999      94_168_23             11.9              3.5  206137.184116
#
#         price_bucket  price_bucket_ctat  price_bucket_vtat
# 0                  0          29.126926           8.283577
# 1                  1          29.069894           8.250120
# 2                  2          28.865348           8.671032
# 3                  2          28.865348           8.671032
# 4                  2          28.865348           8.671032
# ...              ...                ...                ...
# 149995             3          29.283535           8.333253
# 149996             1          29.069894           8.250120
# 149997             0          29.126926           8.283577
# 149998             3          29.283535           8.333253
# 149999             3          29.283535           8.333253
#
# [150000 rows x 85 columns]

# %% [markdown]
# ## Google maps

# %%
from IPython.display import IFrame

def show_route(df, idx=0):
    pickup = df.loc[idx, "Pickup Location"]
    drop = df.loc[idx, "Drop Location"]

    url = f"https://www.google.com/maps?q={pickup.replace(' ', '+')}+to+{drop.replace(' ', '+')}&output=embed"

    return IFrame(url, width=1100, height=600)

show_route(df, idx=0)
# Out:
#         <iframe
#             width="1100"
#             height="600"
#             src="https://www.google.com/maps?q=Pasar+Baru+to+Cilandak+Timur&output=embed"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## Multiple ride maps

# %%
from geopy.geocoders import Nominatim
import time

geolocator = Nominatim(user_agent="ride_app")

def get_lat_lon(location):
    try:
        loc = geolocator.geocode(location)
        time.sleep(1)  # To respect the usage policy of Nominatim
        return loc.latitude, loc.longitude
    except:
        return None, None

# %% [markdown]
# ## Function for distance pickup location - drop location estimation on google maps

# %%
df_sample = df.head(20).copy()
df_sample["pickup_lat"], df_sample["pickup_lon"] = zip(*df_sample["Pickup Location"].apply(get_lat_lon))
df_sample["drop_lat"], df_sample["drop_lon"] = zip(*df_sample["Drop Location"].apply(get_lat_lon))
df_sample.head()
# Out:
#         Date      Time    Booking ID       Booking Status   Customer ID  \
# 0 2024-01-01  00:19:34  "CNR4352144"            Completed  "CID8362794"
# 1 2024-01-01  01:35:18  "CNR9147645"            Completed  "CID8300238"
# 2 2024-01-01  01:37:50  "CNR1009222"  Cancelled by Driver  "CID2030746"
# 3 2024-01-01  01:48:03  "CNR2740479"  Cancelled by Driver  "CID3231181"
# 4 2024-01-01  01:49:56  "CNR7650148"  Cancelled by Driver  "CID3381661"
#
#   Vehicle Type Pickup Location   Drop Location  Avg VTAT  Avg CTAT  \
# 0         Bike      Pasar Baru  Cilandak Timur      10.8      38.9
# 1      Go Mini      Kali Anyar      Rawamangun       8.5      15.1
# 2     Go Sedan         Serdang      Pengadegan       7.4      28.8
# 3         Auto    Tanah Tinggi    Kampung Rawa       5.6      28.8
# 4     Go Sedan            Jati      Batu Ceper       6.2      28.8
#
#    Booking Value  Ride Distance  Driver Ratings  Customer Rating  \
# 0        99000.0          37.98             4.8              4.8
# 1       114000.0          39.29             4.2              4.1
# 2       414000.0          23.72             4.3              4.5
# 3       414000.0          23.72             4.3              4.5
# 4       414000.0          23.72             4.3              4.5
#
#   Payment Method Cancelled Rides by Customer  \
# 0           Cash             No Cancellation
# 1    Uber Wallet             No Cancellation
# 2     Debit Card             No Cancellation
# 3     Debit Card                   Cancelled
# 4     Debit Card             No Cancellation
#
#   Reason for cancelling by Customer Cancelled Rides by Driver  \
# 0                   No Cancellation           No Cancellation
# 1                No Reason Provided                 Cancelled
# 2                      Changed Mind           No Cancellation
# 3                 Found Alternative                 Cancelled
# 4                 Booked by Mistake                 Cancelled
#
#   Driver Cancellation Reason  Incomplete Rides Incomplete Rides Reason  \
# 0            No Cancellation               0.0         No Cancellation
# 1             Personal Issue               1.0   Ride Cancelled Midway
# 2              Traffic Issue               0.0   Ride Cancelled Midway
# 3              Traffic Issue               0.0           Route Problem
# 4          Vehicle Breakdown               0.0               App Error
#
#              Datetime  hour  day_of_week  Pickup Encoded  Drop Encoded  \
# 0 2024-01-01 00:19:34     0            0             110            18
# 1 2024-01-01 01:35:18     1            0              47           147
# 2 2024-01-01 01:37:50     1            0             147           125
# 3 2024-01-01 01:48:03     1            0             160            61
# 4 2024-01-01 01:49:56     1            0              40             2
#
#    route_cluster  distance_per_hour  log_distance  distance_squared  \
# 0              4           4.312727      3.663049         1442.4804
# 1              3           4.312727      3.696103         1543.7041
# 2              1           4.312727      3.207613          562.6384
# 3              2           4.312727      3.207613          562.6384
# 4              0           4.312727      3.207613          562.6384
#
#    distance_sqrt  is_peak_hour  is_weekend  is_night  hour_sin  hour_cos  \
# 0       6.162792             0           0         1  0.000000  1.000000
# 1       6.268174             0           0         1  0.258819  0.965926
# 2       4.870318             0           0         1  0.258819  0.965926
# 3       4.870318             0           0         1  0.258819  0.965926
# 4       4.870318             0           0         1  0.258819  0.965926
#
#    day_sin  day_cos  traffic_score  route_avg_ctat_safe  rating_diff  \
# 0      0.0      1.0              1            29.026393          0.0
# 1      0.0      1.0              1            29.026393          0.1
# 2      0.0      1.0              1            29.026393         -0.2
# 3      0.0      1.0              1            29.026393         -0.2
# 4      0.0      1.0              1            29.026393         -0.2
#
#    avg_rating  low_driver_rating  low_customer_rating  driver_score  \
# 0       4.625                  0                    0           4.8
# 1       4.150                  0                    1           0.0
# 2       4.400                  0                    0           4.3
# 3       4.400                  0                    0           0.0
# 4       4.400                  0                    0           0.0
#
#    hourly_demand  route_demand  demand_pressure  route_count  log_price  \
# 0           1373             5       228.833333            5  11.502885
# 1           1360             2       453.333333            2  11.643962
# 2           1360             4       272.000000            4  12.933624
# 3           1360             7       170.000000            7  12.933624
# 4           1360             7       170.000000            7  12.933624
#
#    log_ctat  log_route_count  log_route_price  log_route_ctat  \
# 0  3.686376         1.791759        12.700787        3.394508
# 1  2.778819         1.098612        12.700787        3.394508
# 2  3.394508         1.609438        12.700787        3.394508
# 3  3.394508         2.079442        12.700787        3.394508
# 4  3.394508         2.079442        12.700787        3.394508
#
#    time_distance_interaction  route_complexity  peak_pressure  \
# 0                      37.98                 5              0
# 1                      39.29                 2              0
# 2                      23.72                 4              0
# 3                      23.72                 7              0
# 4                      23.72                 7              0
#
#    route_ctat_mean  route_ctat_median  route_ctat_std  route_vtat_mean  \
# 0        30.820000               31.2        9.496684         9.620000
# 1        18.300000               18.3        4.525483         7.000000
# 2        28.750000               28.8        0.100000        10.900000
# 3        25.914286               25.9        3.223057         6.571429
# 4        23.542857               20.6        6.484303         5.514286
#
#    route_vtat_median  hour_avg_ctat  hour_avg_vtat  hour_demand  dow_avg_ctat  \
# 0               10.8      29.024763       8.400510         1373     28.940847
# 1                7.0      28.935515       8.381618         1360     28.940847
# 2                9.2      28.935515       8.381618         1360     28.940847
# 3                5.6      28.935515       8.381618         1360     28.940847
# 4                6.2      28.935515       8.381618         1360     28.940847
#
#    dow_avg_vtat  distance_bin  dist_bin_ctat  dist_bin_vtat  log_distance_v2  \
# 0      8.432545             3      30.060481       8.487883         7.010743
# 1      8.432545             3      30.060481       8.487883         7.105852
# 2      8.432545             2      29.119842       8.707975         5.744773
# 3      8.432545             2      29.119842       8.707975         5.744773
# 4      8.432545             2      29.119842       8.707975         5.744773
#
#    rating_sum  rating_mult  rating_min  rating_max  rating_bucket  \
# 0         9.6        23.04         4.8         4.8              4
# 1         8.3        17.22         4.1         4.2              3
# 2         8.8        19.35         4.3         4.5              3
# 3         8.8        19.35         4.3         4.5              3
# 4         8.8        19.35         4.3         4.5              3
#
#    rating_bucket_ctat  rating_bucket_vtat route_hour_key  route_hour_ctat  \
# 0           29.983461            8.483689       110_18_0             38.9
# 1           28.674842            8.418815       47_147_1             15.1
# 2           28.674842            8.418815      147_125_1             28.8
# 3           28.674842            8.418815       160_61_1             28.8
# 4           28.674842            8.418815         40_2_1             28.8
#
#    route_hour_vtat  price_per_km  price_bucket  price_bucket_ctat  \
# 0             10.8   2599.789916             0          29.126926
# 1              8.5   2894.135567             1          29.069894
# 2              7.4  17380.352645             2          28.865348
# 3              5.6  17380.352645             2          28.865348
# 4              6.2  17380.352645             2          28.865348
#
#    price_bucket_vtat  pickup_lat  pickup_lon  drop_lat    drop_lon
# 0           8.283577   -6.164901  106.833467 -6.289466  106.812477
# 1           8.250120   -7.549707  110.817271 -6.195928  106.884725
# 2           8.671032    3.034065  101.705568 -6.248914  106.854349
# 3           8.671032   57.506636   -5.003837 -6.179512  106.855659
# 4           8.671032   -7.689434  -39.006074 -6.172027  106.665287

# %%
# Interactive Map with Folium (Direct Display)
import folium
from folium import plugins
import pandas as pd

# Calculate center coordinates
center_lat = df_sample["pickup_lat"].mean()
center_lon = df_sample["pickup_lon"].mean()

# Create folium map
ride_map = folium.Map(
    location=[center_lat, center_lon],
    zoom_start=12,
    tiles='OpenStreetMap'
)

# Plot all routes
for idx, (_, row) in enumerate(df_sample.head(20).iterrows()):
    if all([
        row["pickup_lat"] is not None,
        row["pickup_lon"] is not None,
        row["drop_lat"] is not None,
        row["drop_lon"] is not None,
        pd.notna(row["pickup_lat"]),
        pd.notna(row["drop_lat"])
    ]):
        try:
            # Pickup marker (green)
            folium.Marker(
                location=[row["pickup_lat"], row["pickup_lon"]],
                popup=f"<b>Pickup {idx+1}</b><br>Lat: {row['pickup_lat']:.4f}<br>Lon: {row['pickup_lon']:.4f}",
                tooltip=f"Pickup {idx+1}",
                icon=folium.Icon(color='green', icon='play', icon_color='white')
            ).add_to(ride_map)
            
            # Drop marker (red)
            folium.Marker(
                location=[row["drop_lat"], row["drop_lon"]],
                popup=f"<b>Drop {idx+1}</b><br>Lat: {row['drop_lat']:.4f}<br>Lon: {row['drop_lon']:.4f}",
                tooltip=f"Drop {idx+1}",
                icon=folium.Icon(color='red', icon='stop', icon_color='white')
            ).add_to(ride_map)
            
            # Draw route line
            folium.PolyLine(
                locations=[
                    [row["pickup_lat"], row["pickup_lon"]],
                    [row["drop_lat"], row["drop_lon"]]
                ],
                color='blue',
                weight=2,
                opacity=0.7,
                popup=f"Route {idx+1}"
            ).add_to(ride_map)
            
        except Exception as e:
            print(f"Error plotting route {idx+1}: {e}")

# Add title/legend
title_html = '''
             <div style="position: fixed; 
                     top: 10px; left: 35px; width: 180px; height: 120px; 
                     background-color: white; border:2px solid grey; z-index:9999; 
                     font-size:14px; padding: 10px; border-radius: 5px;">
             <b style="font-size: 16px;">Routes Overview</b><br>
             🟢 Green: Pickup Location<br>
             🔴 Red: Drop Location<br>
             🔵 Blue: Ride Route<br>
             <b>Total Routes:</b> {}</div>
             '''.format(len(df_sample))

ride_map.get_root().html.add_child(folium.Element(title_html))

print(f"✓ Interactive map generated with {len(df_sample)} routes")
print(f"✓ Map center: ({center_lat:.4f}, {center_lon:.4f})")

# Display directly
ride_map
# Out:
# ✓ Interactive map generated with 20 routes
# ✓ Map center: (-2.7022, 93.8944)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c72e07505cb03ff31aabd9fa1af6eb35 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#              &lt;div style=&quot;position: fixed;
#                      top: 10px; left: 35px; width: 180px; height: 120px;
#                      background-color: white; border:2px solid grey; z-index:9999;
#                      font-size:14px; padding: 10px; border-radius: 5px;&quot;&gt;
#              &lt;b style=&quot;font-size: 16px;&quot;&gt;Routes Overview&lt;/b&gt;&lt;br&gt;
#              🟢 Green: Pickup Location&lt;br&gt;
#              🔴 Red: Drop Location&lt;br&gt;
#              🔵 Blue: Ride Route&lt;br&gt;
#              &lt;b&gt;Total Routes:&lt;/b&gt; 20&lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c72e07505cb03ff31aabd9fa1af6eb35&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c72e07505cb03ff31aabd9fa1af6eb35 = L.map(
#                 &quot;map_c72e07505cb03ff31aabd9fa1af6eb35&quot;,
#                 {
#                     center: [-2.7021651999999996, 93.89437534000001],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1f913fa7707858537a9c7f5607e1914d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1f913fa7707858537a9c7f5607e1914d.addTo(map_c72e07505cb03ff31aabd9fa1af6eb35);
#
#
#             var marker_22f1b0b7fa62b875da9d8006880b06d9 = L.marker(
#                 [-6.164901, 106.8334669],
#                 {
# }
#             ).addTo(map_c72e07505cb03ff31aabd9fa1af6eb35);
#
#
#             var icon_8df498fa424677aa633173273c5cfe84 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;play&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_ebbda2ad83f9875f0297c679cdedf913 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_534799a0901d648028f266b19af45e9a = $(`&lt;div id=&quot;html_534799a0901d648028f266b19af45e9a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Pickup 1&lt;/b&gt;&lt;br&gt;Lat: -6.1649&lt;br&gt;Lon: 106.8335&lt;/div&gt;`)[0];
#                 popup_ebbda2ad83f9875f0297c679cdedf913.setContent(html_534799a0901d648028f266b19af45e9a);
#
#
#
#         marker_22f1b0b7fa62b875da9d8006880b06d9.bindPopup(popup_ebbda2ad83f9875f0297c679cdedf913)
#         ;
#
#
#
#
#             marker_22f1b0b7fa62b875da9d8006880b06d9.bindTooltip(
#                 `&lt;div&gt;
#                      Pickup 1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_22f1b0b7fa62b875da9d8006880b06d9.setIcon(icon_8df498fa424677aa633173273c5cfe84);
#
#
#             var marker_a864dfb4be05da6110368b9bf00d37b1 = L.marker(
#                 [-6.2894658, 106.8124767],
#                 {
# }
#             ).addTo(map_c72e07505cb03ff31aabd9fa1af6eb35);
#
#
#             var icon_4088b93a29de53fa80aa8ffcab03a2c1 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;stop&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_2cb9dc9c1fd73b2c6f2f97fef33ab87a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dd1f2fdcc8afaeef20393528269fc7cd = $(`&lt;div id=&quot;html_dd1f2fdcc8afaeef20393528269fc7cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Drop 1&lt;/b&gt;&lt;br&gt;Lat: -6.2895&lt;br&gt;Lon: 106.8125&lt;/div&gt;`)[0];
#                 popup_2cb9dc9c1fd73b2c6f2f97fef33ab87a.setContent(html_dd1f2fdcc8afaeef20393528269fc7cd);
#
#
#
#         marker_a864dfb4be05da6110368b9bf00d37b1.bindPopup(popup_2cb9dc9c1fd73b2c6f2f97fef33ab87a)
#         ;
#
#
#
#
#             marker_a864dfb4be05da6110368b9bf00d37b1.bindTooltip(
#                 `&lt;div&gt;
#                      Drop 1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_a864dfb4be05da6110368b9bf00d37b1.setIcon(icon_4088b93a29de53fa80aa8ffcab03a2c1);
#
#
#             var poly_line_167228b11337d104aae3a23f3c6ac39f = L.polyline(
#                 [[-6.164901, 106.8334669], [-6.2894658, 10

# %% [markdown]
# ## Create route effience

# %%
df["Efficiency_routes"] = df["Ride Distance"] / df["Avg CTAT"] # Efficiency = Distance / Time average speed (km/h)

top_routes = (
    df.groupby(["Pickup Location", "Drop Location"])
    .agg({
        "Efficiency_routes": "mean",
        "Avg CTAT": "mean",
        "Ride Distance": "mean",
        "route_count": "mean"
    })
    .sort_values(by="Efficiency_routes", ascending=False).head(20)
)
top_routes
# Out:
#                                           Efficiency_routes   Avg CTAT  \
# Pickup Location      Drop Location
# Cilandak Timur       Cempaka Putih Barat           3.046452  15.500000
# Cililitan            Utan Kayu Selatan             3.043506  15.600000
# Kemang               Cempaka Baru                  2.910526  15.200000
# Koja                 Kembangan Utara               2.819228  17.750000
# Kebon Sirih          Cakung Timur                  2.787952  16.600000
# Mangga Dua Selatan   Cipete Utara                  2.787898  15.700000
# Grogol               Kramat Jati                   2.768263  16.700000
# Senen                Maphar                        2.748077  15.600000
# Kali Anyar           Kampung Melayu                2.582051  15.600000
# Pasar Baru           Pisangan Timur                2.575148  16.900000
# Tanjung Barat        Pondok Pinang                 2.547230  15.750000
# Sunter Agung         Kramat Jati                   2.525786  15.900000
# Kelapa Gading Barat  Mampang Prapatan              2.514969  20.350000
# Kamal                Gedong                        2.493567  17.100000
# Duri Utara           Pengadegan                    2.488893  18.633333
# Cililitan            Tanah Sareal                  2.429268  20.500000
# Cilangkap            Sunter Agung                  2.418244  18.150000
# Rawa Bunga           Glodok                        2.395055  18.200000
# Kalideres            Batu Ceper                    2.390863  19.700000
# Halim Perdana Kusuma Kebon Kosong                  2.382022  17.800000
#
#                                           Ride Distance  route_count
# Pickup Location      Drop Location
# Cilandak Timur       Cempaka Putih Barat      47.220000          1.0
# Cililitan            Utan Kayu Selatan        47.490000          2.0
# Kemang               Cempaka Baru             44.240000          1.0
# Koja                 Kembangan Utara          49.400000          2.0
# Kebon Sirih          Cakung Timur             46.280000          1.0
# Mangga Dua Selatan   Cipete Utara             43.770000          1.0
# Grogol               Kramat Jati              46.230000          1.0
# Senen                Maphar                   42.870000          1.0
# Kali Anyar           Kampung Melayu           40.280000          1.0
# Pasar Baru           Pisangan Timur           43.520000          1.0
# Tanjung Barat        Pondok Pinang            40.195000          2.0
# Sunter Agung         Kramat Jati              40.160000          1.0
# Kelapa Gading Barat  Mampang Prapatan         49.165000          2.0
# Kamal                Gedong                   42.640000          1.0
# Duri Utara           Pengadegan               44.643333          3.0
# Cililitan            Tanah Sareal             49.800000          1.0
# Cilangkap            Sunter Agung             43.970000          2.0
# Rawa Bunga           Glodok                   43.590000          1.0
# Kalideres            Batu Ceper               47.100000          1.0
# Halim Perdana Kusuma Kebon Kosong             42.400000          1.0

# %%
# Create plot for efficiency routes (simple approach)
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
route_names = [f"{pickup} → {drop}" for pickup, drop in top_routes.index]
plt.barh(route_names, top_routes["Efficiency_routes"], color='skyblue')
plt.title("Top 20 Most Efficient Routes (Distance/Time)", fontsize=16)
plt.xlabel("Efficiency (km/h)", fontsize=14)
plt.ylabel("Route (Pickup → Drop)", fontsize=14)
plt.tight_layout()
plt.show()

# %%
# Create traffic heatmap
from folium.plugins import HeatMap

m = folium.Map(location=[center_lat, center_lon], zoom_start=12)
heat_data = df_sample[["pickup_lat", "pickup_lon"]].dropna().values.tolist()
HeatMap(heat_data).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_500e5f3fd5dc712cb1fd6a1143fb14cb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_500e5f3fd5dc712cb1fd6a1143fb14cb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_500e5f3fd5dc712cb1fd6a1143fb14cb = L.map(
#                 &quot;map_500e5f3fd5dc712cb1fd6a1143fb14cb&quot;,
#                 {
#                     center: [-2.7021651999999996, 93.89437534000001],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6359bee41fe056d218f3b27f6ab59a8f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6359bee41fe056d218f3b27f6ab59a8f.addTo(map_500e5f3fd5dc712cb1fd6a1143fb14cb);
#
#
#             var heat_map_6d33a470fa0157da0b5bdca624e16df5 = L.heatLayer(
#                 [[-6.164901, 106.8334669], [-7.5497068, 110.8172706], [3.0340649, 101.7055684], [57.5066357, -5.0038367], [-7.6894344, -39.006074], [-6.1911085, 106.8906053], [-6.1682935, 106.9042145], [-6.1736811, 106.8092825], [-6.1859109, 106.8325657], [-6.3518261, 106.8016288], [-6.2125672, 106.8597528], [-6.2328614, 106.8549546], [-6.2079197, 106.7972321], [-6.3301011, 106.8222371], [-6.17182, 106.7824559], [-6.1896703, 106.7908831], [-6.1447372, 106.8007792], [-6.1642923, 106.8247393], [-6.1834535, 106.9648598], [-6.2717196, 106.8049209]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 25,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_6d33a470fa0157da0b5bdca624e16df5.addTo(map_500e5f3fd5dc712cb1fd6a1143fb14cb);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df
# Out:
#              Date      Time    Booking ID       Booking Status   Customer ID  \
# 0      2024-01-01  00:19:34  "CNR4352144"            Completed  "CID8362794"
# 1      2024-01-01  01:35:18  "CNR9147645"            Completed  "CID8300238"
# 2      2024-01-01  01:37:50  "CNR1009222"  Cancelled by Driver  "CID2030746"
# 3      2024-01-01  01:48:03  "CNR2740479"  Cancelled by Driver  "CID3231181"
# 4      2024-01-01  01:49:56  "CNR7650148"  Cancelled by Driver  "CID3381661"
# ...           ...       ...           ...                  ...           ...
# 149995 2024-12-30  22:58:00  "CNR9030698"            Completed  "CID6939658"
# 149996 2024-12-30  23:03:14  "CNR1507833"            Completed  "CID9905090"
# 149997 2024-12-30  23:17:05  "CNR2265113"            Completed  "CID4170406"
# 149998 2024-12-30  23:21:12  "CNR4066733"            Completed  "CID8938559"
# 149999 2024-12-30  23:36:11  "CNR6915581"           Incomplete  "CID5185745"
#
#        Vehicle Type   Pickup Location    Drop Location  Avg VTAT  Avg CTAT  \
# 0              Bike        Pasar Baru   Cilandak Timur      10.8      38.9
# 1           Go Mini        Kali Anyar       Rawamangun       8.5      15.1
# 2          Go Sedan           Serdang       Pengadegan       7.4      28.8
# 3              Auto      Tanah Tinggi     Kampung Rawa       5.6      28.8
# 4          Go Sedan              Jati       Batu Ceper       6.2      28.8
# ...             ...               ...              ...       ...       ...
# 149995         Bike              Setu  Kembangan Utara       6.9      35.8
# 149996        eBike        Jatinegara   Grogol Selatan       7.9      33.6
# 149997      Go Mini      Kebon Melati            Galur       9.9      39.9
# 149998      Uber XL      Utan Panjang     Pinang Ranti       2.6      26.7
# 149999         Auto  Mampang Prapatan     Tegal Parang       3.5      11.9
#
#         Booking Value  Ride Distance  Driver Ratings  Customer Rating  \
# 0             99000.0          37.98             4.8              4.8
# 1            114000.0          39.29             4.2              4.1
# 2            414000.0          23.72             4.3              4.5
# 3            414000.0          23.72             4.3              4.5
# 4            414000.0          23.72             4.3              4.5
# ...               ...            ...             ...              ...
# 149995       440000.0          12.85             4.4              4.8
# 149996       279000.0          39.36             3.8              4.3
# 149997         1855.0          38.91             4.3              4.6
# 149998       520000.0          36.37             5.0              4.3
# 149999       571000.0           2.67             4.3              4.5
#
#        Payment Method Cancelled Rides by Customer  \
# 0                Cash             No Cancellation
# 1         Uber Wallet             No Cancellation
# 2          Debit Card             No Cancellation
# 3          Debit Card                   Cancelled
# 4          Debit Card             No Cancellation
# ...               ...                         ...
# 149995            UPI                   Cancelled
# 149996            UPI             No Cancellation
# 149997            UPI                   Cancelled
# 149998    Uber Wallet             No Cancellation
# 149999            UPI             No Cancellation
#
#        Reason for cancelling by Customer Cancelled Rides by Driver  \
# 0                        No Cancellation           No Cancellation
# 1                     No Reason Provided                 Cancelled
# 2                           Changed Mind           No Cancellation
# 3                      Found Alternative                 Cancelled
# 4                      Booked by Mistake                 Cancelled
# ...                                  ...                       ...
# 149995            Driver Taking Too Long                 Cancelled
# 149996                      Changed Mind                 Cancelled
# 149997                 Booked by Mistake           No Cancellation
# 149998                 Booked by Mistake           No Cancellation
# 149999                      Changed Mind                 Cancelled
#
#        Driver Cancellation Reason  Incomplete Rides Incomplete Rides Reason  \
# 0                 No Cancellation               0.0         No Cancellation
# 1                  Personal Issue               1.0   Ride Cancelled Midway
# 2                   Traffic Issue               0.0   Ride Cancelled Midway
# 3                   Traffic Issue               0.0           Route Problem
# 4               Vehicle Breakdown               0.0               App Error
# ...                           ...               ...                     ...
# 149995         No Reason Provided               1.0               App Error
# 149996       Customer Unreachable               0.0      No Reason Provided
# 149997          Vehicle Breakdown               0.0      No Reason Provided
# 149998       Customer Unreachable               0.0       Vehicle Breakdown
# 149999             Personal Issue               0.0      No Reason Provided
#
#                   Datetime  hour  day_of_week  Pickup Encoded  Drop Encoded  \
# 0      2024-01-01 00:19:34     0            0             110            18
# 1      2024-01-01 01:35:18     1            0              47           147
# 2      2024-01-01 01:37:50     1            0             147           125
# 3      2024-01-01 01:48:03     1            0             160            61
# 4      2024-01-01 01:49:56     1            0              40             2
# ...                    ...   ...          ...             ...           ...
# 149995 2024-12-30 22:58:00    22            0             148            84
# 149996 2024-12-30 23:03:14    23            0              41            43
# 149997 2024-12-30 23:17:05    23            0              69            36
# 149998 2024-12-30 23:21:12    23            0             174           132
# 149999 2024-12-30 23:36:11    23            0              94           168
#
#         route_cluster  distance_per_hour  log_distance  distance_squared  \
# 0                   4           4.312727      3.663049         1442.4804
# 1                   3           4.312727      3.696103         1543.7041
# 2                   1           4.312727      3.207613          562.6384
# 3                   2           4.312727      3.207613          562.6384
# 4                   0           4.312727      3.207613          562.6384
# ...               ...                ...           ...               ...
# 149995              2           0.558696      2.628285          165.1225
# 149996              0           1.640000      3.697839         1549.2096
# 149997              4           1.621250      3.686627         1513.9881
# 149998              1           1.515417      3.620868         1322.7769
# 149999              1           0.111250      1.300192            7.1289
#
#         distance_sqrt  is_peak_hour  is_weekend  is_night  hour_sin  hour_cos  \
# 0            6.162792             0           0         1  0.000000  1.000000
# 1            6.268174             0           0         1  0.258819  0.965926
# 2            4.870318             0           0         1  0.258819  0.965926
# 3            4.870318             0           0         1  0.258819  0.965926
# 4            4.870318             0           0         1  0.258819  0.965926
# ...               ...           ...         ...       ...       ...       ...
# 149995       3.584690             0           0         1 -0.500000  0.866025
# 149996       6.273755             0           0         1 -0.258819  0.965926
# 149997       6.237788             0           0         1 -0.258819  0.965926
# 149998       6.030755             0           0         1 -0.258819  0.965926
# 149999       1.634013             0           0         1 -0.258819  0.965926
#
#         day_sin  day_cos  traffic_score  route_avg_ctat_safe  rating_diff  \
# 0           0.0      1.0              1            29.026393         0.00
# 1           0.0      1.0              1            29.026393         0.10
# 2           0.0      1.0              1            29.026393        -0.20
# 3           0.0      1.0              1            29.026393        -0.20
# 4           0.0      1.0              1            29.026393        -0.20
# ...         ...      ...            ...                  ...          ...
# 149995      0.0      1.0              1            25.260000        -0.40
# 149996      0.0      1.0              1            25.633333        -0.50
# 149997      0.0      1.0              1            27.000000        -0.30
# 149998      0.0      1.0              1            25.833333         0.45
# 149999      0.0      1.0              1            29.666667        -0.20
#
#         avg_rating  low_driver_rating  low_customer_rating  driver_score  \
# 0            4.625                  0                    0           4.8
# 1            4.150                  0                    1           0.0
# 2            4.400                  0                    0           4.3
# 3            4.400                  0                    0           0.0
# 4            4.400                  0                    0           0.0
# ...            ...                ...                  ...           ...
# 149995       4.600                  0                    0           0.0
# 149996       4.050                  1                    0           0.0
# 149997       4.450                  0                    0           4.3
# 149998       4.625                  0                    0           5.0
# 149999       4.400                  0                    0           0.0
#
#         hourly_demand  route_demand  demand_pressure  route_count  log_price  \
# 0                1373             5       228.833333            5  11.502885
# 1                1360             2       453.333333            2  11.643962
# 2                1360             4       272.000000            4  12.933624
# 3                1360             7       170.000000            7  12.933624
# 4                1360             7       170.000000            7  12.933624
# ...               ...           ...              ...          ...        ...
# 149995           5441             6       777.285714            6  12.994532
# 149996           2762             4       552.400000            4  12.538971
# 149997           2762             5       460.333333            5   7.526179
# 149998           2762             4       552.400000            4  13.161586
# 149999           2762            10       251.090909           10  13.255146
#
#         log_ctat  log_route_count  log_route_price  log_route_ctat  \
# 0       3.686376         1.791759        12.700787        3.394508
# 1       2.778819         1.098612        12.700787        3.394508
# 2       3.394508         1.609438        12.700787        3.394508
# 3       3.394508         2.079442        12.700787        3.394508
# 4       3.394508         2.079442        12.700787        3.394508
# ...          ...              ...              ...             ...
# 149995  3.605498         1.945910        12.742693        3.268047
# 149996  3.543854         1.609438        12.331425        3.282164
# 149997  3.711130         1.791759        13.003582        3.332205
# 149998  3.321432         1.609438        12.861867        3.289645
# 149999  2.557227         2.397895        12.865608        3.423176
#
#         time_distance_interaction  route_complexity  peak_pressure  \
# 0                           37.98                 5              0
# 1                           39.29                 2              0
# 2                           23.72                 4              0
# 3                           23.72                 7              0
# 4                           23.72                 7              0
# ...                           ...               ...            ...
# 149995                      12.85                 6              0
# 149996                      39.36                 4              0
# 149997                      38.91                 5              0
# 149998                      36.37                 4              0
# 149999                       2.67                10              0
#
#         route_ctat_mean  route_ctat_median  route_ctat_std  route_vtat_mean  \
# 0             30.820000              31.20        9.496684         9.620000
# 1             18.300000              18.30        4.525483         7.000000
# 2             28.750000              28.80        0.100000        10.900000
# 3             25.914286              25.90        3.223057         6.571429
# 4             23.542857              20.60        6.484303         5.514286
# ...                 ...                ...             ...              ...
# 149995        27.016667              26.15        6.237120         8.683333
# 149996        27.625000              27.30       10.463389         7.750000
# 149997        29.580000              28.80        8.277802         8.020000
# 149998        26.050000              26.30        2.487971         6.675000
# 149999        27.890000              28.80        6.833813         8.140000
#
#         route_vtat_median  hour_avg_ctat  hour_avg_vtat  hour_demand  \
# 0                   10.80      29.024763       8.400510         1373
# 1                    7.00      28.935515       8.381618         1360
# 2                    9.20      28.935515       8.381618         1360
# 3                    5.60      28.935515       8.381618         1360
# 4                    6.20      28.935515       8.381618         1360
# ...                   ...            ...            ...          ...
# 149995               7.95      29.112571       8.432659         5441
# 149996               8.60      28.868356       8.447502         2762
# 149997               9.90      28.868356       8.447502         2762
# 149998               6.65      28.868356       8.447502         2762
# 149999               8.35      28.868356       8.447502         2762
#
#         dow_avg_ctat  dow_avg_vtat  distance_bin  dist_bin_ctat  \
# 0          28.940847      8.432545             3      30.060481
# 1          28.940847      8.432545             3      30.060481
# 2          28.940847      8.432545             2      29.119842
# 3          28.940847      8.432545             2      29.119842
# 4          28.940847      8.432545             2      29.119842
# ...              ...           ...           ...            ...
# 149995     28.940847      8.432545             1      28.152500
# 149996     28.940847      8.432545             3      30.060481
# 149997     28.940847      8.432545             3      30.060481
# 149998     28.940847      8.432545             3      30.060481
# 149999     28.940847      8.432545             0      27.916399
#
#         dist_bin_vtat  log_distance_v2  rating_sum  rating_mult  rating_min  \
# 0            8.487883         7.010743         9.6        23.04         4.8
# 1            8.487883         7.105852         8.3        17.22         4.1
# 2            8.707975         5.744773         8.8        19.35         4.3
# 3            8.707975         5.744773         8.8        19.35         4.3
# 4            8.707975         5.744773         8.8        19.35         4.3
# ...               ...              ...         ...          ...         ...
# 149995       8.043096         4.260973         9.2        21.12         4.4
# 149996       8.487883         7.110858         8.1        16.34         3.8
# 149997       8.487883         7.078542         8.9        19.78         4.3
# 149998       8.487883         6.889998         9.3        21.50         4.3
# 149999       7.952362         1.482556         8.8        19.35         4.3
#
#         rating_max  rating_bucket  rating_bucket_ctat  rating_bucket_vtat  \
# 0              4.8              4           29.983461            8.483689
# 1              4.2              3           28.674842            8.418815
# 2              4.5              3           28.674842            8.418815
# 3              4.5              3           28.674842            8.418815
# 4              4.5              3           28.674842            8.418815
# ...            ...            ...                 ...                 ...
# 149995         4.8              4           29.983461            8.483689
# 149996         4.3              3           28.674842            8.418815
# 149997         4.6              3           28.674842            8.418815
# 149998         5.0              4           29.983461            8.483689
# 149999         4.5              3           28.674842            8.418815
#
#        route_hour_key  route_hour_ctat  route_hour_vtat   price_per_km  \
# 0            110_18_0             38.9             10.8    2599.789916
# 1            47_147_1             15.1              8.5    2894.135567
# 2           147_125_1             28.8              7.4   17380.352645
# 3            160_61_1             28.8              5.6   17380.352645
# 4              40_2_1             28.8              6.2   17380.352645
# ...               ...              ...              ...            ...
# 149995      148_84_22             35.8              6.9   33976.833977
# 149996       41_43_23             33.6              7.9    7070.451090
# 149997       69_36_23             39.9              9.9      47.551910
# 149998     174_132_23             26.7              2.6   14258.294489
# 149999      94_168_23             11.9              3.5  206137.184116
#
#         price_bucket  price_bucket_ctat  price_bucket_vtat  Efficiency_routes
# 0                  0          29.126926           8.283577           0.976350
# 1                  1          29.069894           8.250120           2.601987
# 2                  2          28.865348           8.671032           0.823611
# 3                  2          28.865348           8.671032           0.823611
# 4                  2          28.865348           8.671032           0.823611
# ...              ...                ...                ...                ...
# 149995             3          29.283535           8.333253           0.358939
# 149996             1          29.069894           8.250120           1.171429
# 149997             0          29.126926           8.283577           0.975188
# 149998             3          29.283535           8.333253           1.362172
# 149999             3          29.283535           8.333253           0.224370
#
# [150000 rows x 86 columns]

# %%
# Build mini dashboard cell
def analyze_route(idx):
    row = df.loc[idx]

    print("📍 Pickup:", row["Pickup Location"])
    print("🏁 Drop:", row["Drop Location"])
    print("📏 Distance:", row["Ride Distance"])
    print("⏱ CTAT:", row["Avg CTAT"])
    print("💰 Price:", row["Booking Value"])

    return show_route(df, idx)

# Example usage
analyze_route(1)
# Out:
# 📍 Pickup: Kali Anyar
# 🏁 Drop: Rawamangun
# 📏 Distance: 39.29
# ⏱ CTAT: 15.1
# 💰 Price: 114000.0
#         <iframe
#             width="1100"
#             height="600"
#             src="https://www.google.com/maps?q=Kali+Anyar+to+Rawamangun&output=embed"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
df.loc[idx]
# Out:
# Date                 2024-01-01 00:00:00
# Time                            05:02:51
# Booking ID                  "CNR2812762"
# Booking Status                 Completed
# Customer ID                 "CID3933983"
#                             ...
# price_per_km                11281.128113
# price_bucket                           2
# price_bucket_ctat              28.865348
# price_bucket_vtat               8.671032
# Efficiency_routes               0.957637
# Name: 19, Length: 86, dtype: object
