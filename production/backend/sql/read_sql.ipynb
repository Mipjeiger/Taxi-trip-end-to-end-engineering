# %%
import psycopg2
import pandas as pd
from sqlalchemy import create_engine
from pathlib import Path
from dotenv import load_dotenv
import warnings
import os
warnings.filterwarnings("ignore")

# %%
# Ensure .env file is exists
ENV_PATH = Path.cwd().parents[1] / '.env'
load_dotenv(dotenv_path=ENV_PATH)
print(f"DEBUG -> Host loaded from .env: {os.getenv('POSTGRES_HOST')}")

# Configuration postgresql
POSTGRES_USER = os.getenv("POSTGRES_USER")
POSTGRES_PASSWORD = os.getenv("POSTGRES_PASSWORD")
POSTGRES_HOST = os.getenv("POSTGRES_HOST")
POSTGRES_PORT = os.getenv("POSTGRES_PORT")
POSTGRES_DB = os.getenv("POSTGRES_DB")
# Out:
# DEBUG -> Host loaded from .env: localhost

# %% [markdown]
# ## Connect to Postgresql

# %%
# Connect to PostgreSQL database
try:
    with psycopg2.connect(
        host=POSTGRES_HOST,
        port=POSTGRES_PORT,
        database=POSTGRES_DB,
        user=POSTGRES_USER,
        password=POSTGRES_PASSWORD
    ) as con:
        
        with con.cursor() as cursor:
            # Test connection
            cursor.execute("SELECT version();")
            record = cursor.fetchone()
            print(f"🚀 PostgreSQL database version: {record[0]}")
            print("Connection to PostgreSQL database successful!")
except Exception as e:
    print(f"❌ Error connecting to PostgreSQL database: {e}")
# Out:
# 🚀 PostgreSQL database version: PostgreSQL 15.18 on aarch64-unknown-linux-musl, compiled by gcc (Alpine 15.2.0) 15.2.0, 64-bit
# Connection to PostgreSQL database successful!

# %%
# Define DB url
db_url = f'postgresql+psycopg2://{POSTGRES_USER}:{POSTGRES_PASSWORD}@{POSTGRES_HOST}:{POSTGRES_PORT}/{POSTGRES_DB}'

# Function to load data from PostgreSQL database
def load_data_from_postgres(db_url):
    try:
        engine = create_engine(db_url)
        df = pd.read_sql_table(table_name='trip', con=engine, schema='analytics')
        print("Data loaded successfully from PostgreSQL database!")
        print(f"Loaded {len(df)} rows.")
        return df
    except Exception as e:
        print(f"❌ Error loading data from PostgreSQL database: {e}")
        return None

# %%
# Read database on postgreSQL
df = load_data_from_postgres(db_url)
df
# Out:
# Data loaded successfully from PostgreSQL database!
# Loaded 148767 rows.
#            ride_id     rider_id driver_id   pickup_location dropoff_location  \
# 0       CNR4352144  RIDE-000001      None        Pasar Baru   Cilandak Timur
# 1       CNR9147645  RIDE-000002      None        Kali Anyar       Rawamangun
# 2       CNR1009222  RIDE-000003      None           Serdang       Pengadegan
# 3       CNR2740479  RIDE-000004      None      Tanah Tinggi     Kampung Rawa
# 4       CNR7650148  RIDE-000005      None              Jati       Batu Ceper
# ...            ...          ...       ...               ...              ...
# 148762  CNR9030698  RIDE-149996      None              Setu  Kembangan Utara
# 148763  CNR1507833  RIDE-149997      None        Jatinegara   Grogol Selatan
# 148764  CNR2265113  RIDE-149998      None      Kebon Melati            Galur
# 148765  CNR4066733  RIDE-149999      None      Utan Panjang     Pinang Ranti
# 148766  CNR6915581  RIDE-150000      None  Mampang Prapatan     Tegal Parang
#
#         pickup_lat  pickup_lng  dropoff_lat  dropoff_lng               status  \
# 0        -6.164901  106.833467    -6.289466   106.812477            Completed
# 1        -7.550534  110.819452    -6.195928   106.884725            Completed
# 2         3.034065  101.705568    -6.248914   106.854349  Cancelled by Driver
# 3        57.506636   -5.003837    -6.179512   106.855659  Cancelled by Driver
# 4        -7.689434  -39.006074    -6.172027   106.665287  Cancelled by Driver
# ...            ...         ...          ...          ...                  ...
# 148762   -6.341971  106.664700    -6.173267   106.742726            Completed
# 148763   -6.214925  106.870339    -6.230900   106.780309            Completed
# 148764   -6.197487  106.816546    -7.950719   110.202904            Completed
# 148765   -6.164872  106.854815    -6.288428   106.883331            Completed
# 148766   -6.250894  106.823022    -6.248909   106.829606           Incomplete
#
#          ride_type  estimated_fare  actual_fare  distance_km  \
# 0       Motorcycle             NaN          NaN        37.98
# 1              Car             NaN          NaN        39.29
# 2         Go Sedan             NaN          NaN        23.72
# 3             Auto             NaN          NaN        23.72
# 4         Go Sedan             NaN          NaN        23.72
# ...            ...             ...          ...          ...
# 148762  Motorcycle             NaN          NaN        12.85
# 148763       eBike             NaN          NaN        39.36
# 148764         Car             NaN          NaN        38.91
# 148765     Uber XL             NaN          NaN        36.37
# 148766        Auto             NaN          NaN         2.67
#
#         duration_minutes                 created_at        completed_at
# 0                  11.55 2026-06-03 14:47:53.466567 2026-01-01 00:11:33
# 1                   3.40 2026-06-03 14:47:53.466567 2026-01-01 00:04:24
# 2                   8.60 2026-06-03 14:47:53.466567 2026-01-01 00:10:36
# 3                   5.80 2026-06-03 14:47:53.466567 2026-01-01 00:08:48
# 4                   6.60 2026-06-03 14:47:53.466567 2026-01-01 00:10:36
# ...                  ...                        ...                 ...
# 148762              7.55 2026-06-03 14:47:53.466567 2026-04-15 04:02:33
# 148763              6.30 2026-06-03 14:47:53.466567 2026-04-15 04:02:18
# 148764              4.70 2026-06-03 14:47:53.466567 2026-04-15 04:01:42
# 148765              9.20 2026-06-03 14:47:53.466567 2026-04-15 04:07:12
# 148766             17.10 2026-06-03 14:47:53.466567 2026-04-15 04:16:06
#
# [148767 rows x 17 columns]
